# %% [markdown]
# **Executed:** Tue Feb 28 04:01:52 2017
#
# **Duration:** 1 seconds.
#
# **Autogenerated from:** [./example-template-notebook.ipynb](./example-template-notebook.ipynb)

# %%
data_id = 0          # default data id
analysis_type = 'a'  # default analysis type

# %%
# Cell inserted during automated execution.
data_id = 0
analysis_type = 'b'

# %% [markdown]
# # markdown1

# %%
print(data_id, analysis_type)
# Out:
# 0 b

# %% [markdown]
# # markdown2
