# %% [markdown]
# ## GUI (Graphical User Interface) for doing inferences for network: Asia

# %% [markdown]
# Start by defining bif and dot files for the net.

# %%
in_bif = 'examples_cbnets/asia_.bif'
in_dot = 'examples_cbnets/asia_.dot'

# %% [markdown]
# Change your working directory to the quantum-fog
# directory in your computer, and add its path to the path environment variable.

# %%
import os
import sys
master_dir_path = os.getcwd()
print(master_dir_path)
os.chdir('../../')
qfog_path = os.getcwd()
print(qfog_path)
sys.path.insert(0,qfog_path)
# Out:
# /home/jupyter/Notebooks/Quantum/quantum-fog/jupyter-notebooks/cbnets_inference_gui
# /home/jupyter/Notebooks/Quantum/quantum-fog

# %% [markdown]
# Do necessary imports

# %%
import numpy as np
import pandas as pd
from IPython.display import Image, display, clear_output
from graphviz import Source

# %%
from graphs.BayesNet import *

# %%
import importlib
ut = importlib.import_module("jupyter-notebooks.cbnets_inference_gui.util_widgets")

# %% [markdown]
# Display the graph given by dot file

# %%
Source(open(in_dot).read())

# %% [markdown]
# Create BayesNet object called `bnet` from bif file and create gui from that `bnet`.
#
# One can choose one or more active states for each node.
#
# One can choose to plot one or more nodes.
#
# The red button produces probability bar plots depending
# on which states are known to be active (i.e., the available evidence).
#
# The state of the widgets can be saved or cleared
# before closing the notebook. To do that, visit `Widgets` menu of notebook.

# %%
bnet = BayesNet.read_bif(in_bif, False)
ut.run_gui(bnet)
# Out:
# Label(value='Active states for each node:')
# SelectMultiple(description='Bronchitis:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='Dyspnea:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='Either:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='Lung_Cancer:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='Smoke:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='Tuberculosis:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='Visited_Asian_TB_HRA:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# SelectMultiple(description='X_Ray:', index=(0,), options={'All States': -1, 'yes': 0, 'no': 1}, value=(-1,))
# Label(value='Desired Node Prob Plots:')
# SelectMultiple(index=(0,), options=('All Nodes', 'Bronchitis', 'Dyspnea', 'Either', 'Lung_Cancer', 'Smoke', 'Tuberculosis', 'Visited_Asian_TB_HRA', 'X_Ray'), value=('All Nodes',))
# Button(button_style='danger', description='Refresh Node Prob Plots', layout=Layout(width='40%'), style=ButtonStyle())
# Bronchitis
# Active States: [0, 1]
# ['Bronchitis']
# [ 0.21214877  0.78785123]
#
#
# Dyspnea
# Active States: [1]
# ['Dyspnea']
# [ 0.  1.]
#
#
# Either
# Active States: [0, 1]
# ['Either']
# [ 0.01556786  0.98443214]
#
#
# Lung_Cancer
# Active States: [0, 1]
# ['Lung_Cancer']
# [ 0.01302804  0.98697196]
#
#
# Smoke
# Active States: [0, 1]
# ['Smoke']
# [ 0.41179886  0.58820114]
#
#
# Tuberculosis
# Active States: [0, 1]
# ['Tuberculosis']
# [ 0.00267531  0.99732469]
#
#
# Visited_Asian_TB_HRA
# Active States: [0, 1]
# ['Visited_Asian_TB_HRA']
# [ 0.00970278  0.99029722]
#
#
# X_Ray
# Active States: [0, 1]
# ['X_Ray']
# [ 0.06447811  0.93552189]
